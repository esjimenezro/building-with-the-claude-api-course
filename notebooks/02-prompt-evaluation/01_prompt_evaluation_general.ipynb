# %% [markdown]
# # 01 — Prompt Evaluation
#
# **Objectives:**
# - Understand what prompt evaluation is and how it differs from prompt engineering
# - Assemble our own workflow fro prompt evaluation

# %% [markdown]
# ## 1. Draft a Prompt

# %%
prompt = f"""
Please answer the user's question:

{question}
"""

# %% [markdown]
# ## 2. Create an Eval Dataset

# %%
eval_dataset = [
    "What's 2+2?",
    "How do I make oatmeal?",
    "How far away is the moon?",
]

# %% [markdown]
# ## 3. Feed Through Claude

# %%
# Get the client and model from utils
from src.utils import get_client, get_model

client = get_client()
model = get_model()

# %%
# One way to give the model memory is to include the previous messages in the conversation
# See functions add_user_message, add_assistant_message, and chat in src/utils.py
from src.utils import chat, add_user_message, add_assistant_message

# %% [markdown]
# ## 4. Feed Through a Grader

# %% [markdown]
# ## 5. Iterate the prompt
