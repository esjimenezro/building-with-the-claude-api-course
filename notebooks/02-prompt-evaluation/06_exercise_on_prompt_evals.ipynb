# %% [markdown]
# # 06 — Exercise on prompt evals

# %%
# Add repo root to path
import sys
sys.path.append("../..")

# %%
# Get the client and model from utils
from src.utils import get_client, get_model

client = get_client()
model = get_model()

# %%
# Other imports
from src.prompt_evaluation import generate_dataset, run_eval

# %%
import json

dataset = generate_dataset()

with open('dataset.json', 'w') as f:
    json.dump(dataset, f, indent=2)

# %%
with open('dataset.json', 'r') as f:
    dataset = json.load(f)


results = run_eval(dataset)
# Out:
# Average Score: 8.166666666666666

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\n{\n  \"Version\": \"2012-10-17\",\n  \"Statement\": [\n    {\n      \"Effect\": \"Allow\",\n      \"Action\": [\n        \"s3:GetObject\",\n        \"s3:ListBucket\"\n      ],\n      \"Resource\": [\n        \"arn:aws:s3:::my-app-logs\",\n        \"arn:aws:s3:::my-app-logs/*\"\n      ]\n    }\n  ]\n}\n",
#     "test_case": {
#       "task": "Create a JSON policy document that allows an IAM user to read objects from a specific S3 bucket named 'my-app-logs' and list the bucket contents",
#       "format": "json",
#       "solution_criteria": "Must include correct Version, Statement structure with Effect 'Allow', Principal or not specified for IAM policy, Action including s3:GetObject and s3:ListBucket, Resource ARNs for both bucket and objects with correct syntax"
#     },
#     "score": 9.5,
#     "reasoning": "The solution correctly implements all required criteria with proper JSON structure, necessary S3 permissions, and accurate ARN syntax. It follows AWS IAM policy best practices for granting read-only access to a specific S3 bucket. The policy is minimal yet complete for the stated requirements."
#   },
#   {
#     "output": "\ndef extract_s3_extension(s3_key):\n    if not s3_key or s3_key.endswith('/'):\n        return ''\n    \n    filename = s3_key.split('/')[-1]\n    \n    if '.' not in filename or filename.startswith('.'):\n        return ''\n    \n    return filename.split('.')[-1].lower()\n",
#     "test_case": {
#       "task": "Write a Python function that takes an AWS S3 object key (file path) and extracts the file extension, handling edge cases where there might be no extension",
#       "format": "python",
#       "solution_criteria": "Function should accept a string parameter, handle empty strings and paths without extensions gracefully, return the extension including the dot (e.g., '.txt') or empty string if no extension, and work with nested folder structures"
#     },
#     "score": 8.0,
#     "reasoning": "The solution demonstrates good understanding of S3 key structure and handles most edge cases well, but fails to meet the specific requirement of returning extensions with dot prefix. The lowercase conversion and multiple dot handling also deviate from typical expectations."
#   },
#   {
#     "output": "\n^[a-zA-Z0-9-_]{1,64}$\n",
#     "test_case": {
#       "task": "Create a regular expression pattern that matches valid AWS Lambda function names according to AWS naming conventions",
#       "format": "regex",
#       "solution_criteria": "Must match strings that are 1-64 characters long, contain only letters, numbers, hyphens, and underscores, cannot start or end with hyphen, and should reject invalid names like those starting with numbers or containing spaces"
#     },
#     "score": 7.0,
#     "reasoning": "The regex covers basic length and character set requirements but fails critical AWS Lambda naming constraints. AWS Lambda functions must start with a letter and cannot begin or end with hyphens. The current pattern would incorrectly validate invalid names like '123func', '-invalid', or 'invalid-'."
#   }
# ]
