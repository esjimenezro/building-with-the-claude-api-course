# %% [markdown]
# # 01 — First API Call
#
# **Objectives:**
# - Make first call to Claude API
# - Understand the basic API response structure: `stop_reason`, `usage`, `content`
#
# **Exam domain:** Context Management & Reliability (15%)

# %%
# Add repo root to path
import sys
sys.path.append("../..")

# %%
# Get the client and model from utils
from src.utils import get_client, get_model

client = get_client()
model = get_model()

# %% [markdown]
# ## 1. First API Call

# %%
# Call the API
message = client.messages.create(
    model=model,
    max_tokens=1000,
    messages=[
        {
            "role": "user",
            "content": "What is Claude? Answer in one sentence"
        }
    ]
)

# %%
# Complete response
message
# Out:
# Message(id='msg_01B6vTDEWirvm77MxoTbcakK', container=None, content=[TextBlock(citations=None, text='Claude is an AI assistant created by Anthropic to be helpful, harmless, and honest through conversations with users.', type='text')], model='claude-sonnet-4-20250514', role='assistant', stop_reason='end_turn', stop_sequence=None, type='message', usage=Usage(cache_creation=CacheCreation(ephemeral_1h_input_tokens=0, ephemeral_5m_input_tokens=0), cache_creation_input_tokens=0, cache_read_input_tokens=0, inference_geo='not_available', input_tokens=15, output_tokens=27, server_tool_use=None, service_tier='standard'))

# %%
# Only the text content of the first message in the response
message.content[0].text
# Out:
# 'Claude is an AI assistant created by Anthropic to be helpful, harmless, and honest through conversations with users.'
